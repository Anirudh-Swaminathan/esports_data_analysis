# %% [markdown]
# # Next Permutation #
# ![image.png](attachment:image.png)

# %% [markdown]
# **Validation Tests** <br>
# Check for corner cases and constraints in the inputs enlist all cases used for testing

# %%
# Validation Tests
assert isinstance(t, tuple) and len(t) > 0 # Function should include these
assert len(set(t)) == len(t) and all([i >= 0 for i in t]) # Function should include these

# %%
# Should fail validation tests
next_permutation(('3', '2', '1', '0')) # wrong type
next_permutation((3, 3, 2, 2, 1, 4, 0)) # non-unique input
next_permutation([3, 2, 1, 0]) # wrong iterable type
next_permutation(()) # empty item type
next_permutation((2, 3, -1)) # negative item

# %% [markdown]
# **Functional Tests** <br>
# Check function output matches expected result enlist all cases used for testing

# %%
# Functional Tests
assert next_permutation((6, 5, 4, 3, 2, 1, 0)) == (0, 1, 2, 3, 4, 5, 6) # last permutation

# %%
import time
start = time.time()
assert next_permutation((6, 1, 5, 7, 2, 4, 3, 10, 8, 9)) == (6, 1, 5, 7, 2, 4, 3, 10, 9, 8) # long duration permutations
end = time.time()
assert end-start < 25

# %% [markdown]
# # Frobenius Solver #
# ![image.png](attachment:image.png)

# %% [markdown]
# **Validation Tests** <br>
# Check for corner cases and constraints in the inputs enlist all cases used for testing

# %%
# Validation Tests
assert isinstance(coefs, list) and len(coefs) > 0 # function should include this
assert all([a > 0 for a in coefs]) # function should include this
assert isinstance(b, int) and b >= 0 # function should include this

# %%
# Should fail validation tests
solvefrob([], 0) # empty value
solvefrob([1, 2], 'hello') # incorrect type
solvefrob((1, 2), 3) # incorrect type
solvefrob([0, 1], 2) # contains 0
solvefrob([-1, 5, 2], 10) # negative value

# %% [markdown]
# **Functional Tests** <br>
# Check function output matches expected result enlist all cases used for testing

# %%
# Functional Tests
assert [(1, 2), (3,1), (5,0)] == solvefrob([1, 2], 5)  # basic test
assert [] == solvefrob([7, 8], 12) # no solution
assert [(0, 5), (2, 4), (4, 3), (6, 2), (8, 1), (10, 0)] == solvefrob([5, 10], 50)  # Longer test
